# %%
from dotenv import load_dotenv
load_dotenv()

from crewai import LLM

llm = LLM(
    model="gemini/gemini-2.0-flash",
    temperature=0.1
)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 6
#       2 load_dotenv()
#       4 from crewai import LLM
# ----> 6 llm = LLM(
#       7     model="gemini/gemini-2.0-flash",
#       8     temperature=0.1
#       9 )
#
# File c:\Users\win10\Desktop\crewai-crash-course-main\.venv\Lib\site-packages\crewai\llm.py:385, in LLM.__new__(cls, model, is_litellm, **kwargs)
#     382     use_native = True
#     383     model_string = model
# --> 385 native_class = cls._get_native_provider(provider) if use_native else None
#     386 if native_class and not is_litellm and provider in SUPPORTED_NATIVE_PROVIDERS:
#     387     try:
#     388         # Remove 'provider' from kwargs if it exists to avoid duplicate keyword argument
#
# File c:\Users\win10\Desktop\crewai-crash-course-main\.venv\Lib\site-packages\crewai\llm.py:487, in LLM._get_native_provider(cls, provider)
#     484     return AzureCompletion
#     486 if provider == "google" or provider == "gemini":
# --> 487     from crewai.llms.providers.gemini.completion import GeminiCompletion
#     489     return GeminiCompletion
#     491 if provider == "bedrock":
#
# File c:\Users\win10\Desktop\crewai-crash-course-main\.venv\Lib\site-packages\crewai\llms\providers\gemini\completion.py:23
#      21     from google.genai.errors import APIError  # type: ignore[import-untyped]
#      22 except ImportError:
# ---> 23     raise ImportError(
#      24         'Google Gen AI native provider not available, to install: uv add "crewai[google-genai]"'
#      25     ) from None
#      28 class GeminiCompletion(BaseLLM):
#      29     """Google Gemini native completion implementation.
#      30
#      31     This class provides direct integration with the Google Gen AI Python SDK,
#      32     offering native function calling, streaming support, and proper Gemini formatting.
#      33     """
#
# ImportError: Google Gen AI native provider not available, to install: uv add "crewai[google-genai]"

# %%
from crewai import Agent, Task, Crew
from crewai_tools import SerperDevTool

research_agent = Agent(
    role="Research Specialist",
    goal="Research interesting facts about the topic: {topic}",
    backstory="You are an expert at finding relevant and factual data.",
    tools=[SerperDevTool()],
    verbose=True,
    llm=llm
)

writer_agent = Agent(
    role="Creative Writer",
    goal="Write a short blog summary using the research",
    backstory="You are skilled at writing engaging summaries based on provided content.",
    llm=llm,
    verbose=True,
)

# %%
task1 = Task(
    description="Find 3-5 interesting and recent facts about {topic} as of year 2025.",
    expected_output="A bullet list of 3-5 facts",
    agent=research_agent,
)

task2 = Task(
    description="Write a 100-word blog post summary about {topic} using the facts from the research.",
    expected_output="A blog post summary",
    agent=writer_agent,
    context=[task1],
)

# %%
crew = Crew(
    agents=[research_agent, writer_agent],
    tasks=[task1, task2],
    verbose=True,
)

crew.kickoff(inputs={"topic": "The future of electrical vehicles"})
# Out:
# ╭──────────────────────────────────────────── Crew Execution Started ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Started                                                                                         │
# │  Name: crew                                                                                                     │
# │  ID: 754a1256-c4a3-467b-aafc-60d3b4beda08                                                                       │
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Research Specialist                                                                                     │
# │                                                                                                                 │
# │  Task: Find 3-5 interesting and recent facts about The future of electrical vehicles as of year 2025.           │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# C:\Code\crewai-crash-course\.venv\lib\site-packages\rich\live.py:231: UserWarning: install "ipywidgets" for Jupyter
# support
#   warnings.warn('install "ipywidgets" for Jupyter support')
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭──────────────────────────────────────────── 🔧 Agent Tool Execution ────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Research Specialist                                                                                     │
# │                                                                                                                 │
# │  Thought: I need to find 3-5 interesting and recent facts about the future of electrical vehicles as of year    │
# │  2025. I will use the search tool to find this information. I will start with a broad search and then refine    │
# │  it if necessary.                                                                                               │
# │                                                                                                                 │
# │  Using Tool: Search the internet with Serper                                                                    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭────────────────────────────────────────────────── Tool Input ───────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  "{\"search_query\": \"future of electric vehicles 2025 facts\"}"                                               │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭────────────────────────────────────────────────── Tool Output ──────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  {'searchParameters': {'q': 'future of electric vehicles 2025 facts', 'type': 'search', 'num': 10, 'engine':    │
# │  'google'}, 'organic': [{'title': 'Upcoming Electric Cars: 2025-2030 EVs | U.S. News', 'link':                  │
# │  'https://cars.usnews.com/cars-trucks/advice/future-electric-cars', 'snippet': 'More people are getting on      │
# │  board as the technology continues to improve. Longer driving ranges, quicker charging times, and               │
# │  easier-to-use ...', 'position': 1}, {'title': 'Future EVs: Every Electric Vehicle Coming Soon - Car and        │
# │  Driver', 'link': 'https://www.caranddriver.com/news/g29994375/future-electric-cars-trucks/', 'snippet':        │
# │  "We've compiled a list of every electric vehicle, from concept to production, that isn't available yet but     │
# │  will be soon.", 'position': 2}, {'title': 'Trends in the electric car industry – Global EV Outlook 2025 -      │
# │  IEA', 'link': 'https://www.iea.org/reports/global-ev-outlook-2025/trends-in-the-electric-car-industry-3',      │
# │  'snippet': "In 2025, BYD commissioned the world's largest Ro-Ro vessel, bringing its total shipping capacity   │
# │  to more than 30 000 electric cars.", 'position': 3}, {'title': 'The Future of Electric Vehicles: 7 Factors     │
# │  Driving EV Growth', 'link': 'https://sepapower.org/knowledge/future-of-electric-vehicles/', 'snippet': 'The    │
# │  Edison Electric Institute projects that EVs on U.S. roads will grow to 26.4 million by 2030, making up over    │
# │  10% of vehicles on the road.', 'position': 4}, {'title': 'What to Expect in the Electric Vehicle Industry: EV  │
# │  Trends For 2025', 'link': 'https://www.greenlancer.com/post/ev-market-trends', 'snippet': 'EV trends for 2025  │
# │  include lower electric car prices, an expansion of charging stations, and greater charging plug                │
# │  compatibility.', 'position': 5}, {'title': 'Electric Car Range and Price Comparison 2025 - Coltura', 'link':   │
# │  'https://coltura.org/electric-car-battery-range/', 'snippet': 'There are now almost 70 electric vehicle makes  │
# │  and models available in the US in 2025, from 30 brands - and that number keeps growing. Use this e...          │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# C:\Code\crewai-crash-course\.venv\lib\site-packages\rich\live.py:231: UserWarning: install "ipywidgets" for Jupyter
# support
#   warnings.warn('install "ipywidgets" for Jupyter support')
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭──────────────────────────────────────────── 🔧 Agent Tool Execution ────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Research Specialist                                                                                     │
# │                                                                                                                 │
# │  Thought: Thought: I have the initial search results. Based on these, I can formulate a few interesting facts   │
# │  about the future of EVs in 2025.                                                                               │
# │                                                                                                                 │
# │  Using Tool: Search the internet with Serper                                                                    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭────────────────────────────────────────────────── Tool Input ───────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  "{\"search_query\": \"electric vehicle market trends 2025\"}"                                                  │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭────────────────────────────────────────────────── Tool Output ──────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  {'searchParameters': {'q': 'electric vehicle market trends 2025', 'type': 'search', 'num': 10, 'engine':       │
# │  'google'}, 'organic': [{'title': 'Global EV Outlook 2025 – Analysis - IEA', 'link':                            │
# │  'https://www.iea.org/reports/global-ev-outlook-2025', 'snippet': 'The report draws on the latest data to       │
# │  assess trends in electric vehicle deployment, demand for their batteries and charging infrastructure.',        │
# │  'position': 1}, {'title': 'Electric Vehicle Outlook | BloombergNEF', 'link':                                   │
# │  'https://about.bnef.com/insights/clean-transport/electric-vehicle-outlook/', 'snippet': '25. %. Expected       │
# │  growth in global passenger EV sales in 2025 ; 3 .8TWh. Risk-adjusted lithium-ion cell manufacturing capacity   │
# │  by the end of 2025 – double expected ...', 'position': 2}, {'title': 'U.S. Electric Vehicle Sales Increase     │
# │  More Than 10% Year Over Year ...', 'link': 'https://www.coxautoinc.com/market-insights/q1-2025-ev-sales/',     │
# │  'snippet': "In Q1 2025, the EV pioneer was heading back to earth: Sales of 128,000, down 26% from the peak     │
# │  and with a market share closer to 3%. What's next ...", 'position': 3}, {'title': 'EV Volumes - 2025 EV        │
# │  Statistics, Sales & Market Forecasts', 'link': 'https://ev-volumes.com/', 'snippet': 'Access 2025 electric     │
# │  vehicle sales data, market trends, and forecasts. Explore expert insights on top EV models, BEVs, and          │
# │  charging networks.', 'position': 4}, {'title': 'EV Market Monitor – April 2025 - Cox Automotive Inc.',         │
# │  'link': 'https://www.coxautoinc.com/market-insights/ev-market-monitor-april-2025/', 'snippet': 'The volume of  │
# │  new EV sales declined by 5.9% month over month to 100,495 units, while the EV market share rose slightly to    │
# │  6.9%. Year over year, ...', 'position': 5}, {'title': '2025 EV Sales Surge: Which Countries Are Winning the    │
# │  Electric ...', 'link':                                                                                         │
# │  'https://carboncredits.com/2025-ev-sales-surge-which-countries-are-winning-the-electric-race/', 'snippet':     │
# │  'Global EV sales surge in 2025, with China, Europe, and the U.S. leading. Explore top markets, charging        │
# │  growth, and...                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Research Specialist                                                                                     │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  *   In Q1 2025, global battery electric vehicle (BEV) sales witnessed a year-on-year growth of 42%.            │
# │  *   Global EV sales grew 28% in 2025, with 1.6 million vehicles sold in May 2025 alone.                        │
# │  *   There are now almost 70 electric vehicle makes and models available in the US in 2025, from 30 brands -    │
# │  and that number keeps growing.                                                                                 │
# │  *   In 2025, BYD commissioned the world's largest Ro-Ro vessel, bringing its total shipping capacity to more   │
# │  than 30 000 electric cars.                                                                                     │
# │  *   EV trends for 2025 include lower electric car prices, an expansion of charging stations, and greater       │
# │  charging plug compatibility.                                                                                   │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭──────────────────────────────────────────────── Task Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: 935b1eb4-cefb-49cf-916e-641f923a2009                                                                     │
# │  Agent: Research Specialist                                                                                     │
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Creative Writer                                                                                         │
# │                                                                                                                 │
# │  Task: Write a 100-word blog post summary about The future of electrical vehicles using the facts from the      │
# │  research.                                                                                                      │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Creative Writer                                                                                         │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  **The Road Ahead: Electric Vehicle Trends in 2025**                                                            │
# │                                                                                                                 │
# │  The electric vehicle revolution is accelerating! Q1 2025 saw a 42% surge in global battery electric vehicle    │
# │  (BEV) sales, contributing to an overall 28% growth in EV sales, with 1.6 million vehicles sold in May alone.   │
# │  The US market boasts nearly 70 EV models from 30 brands, offering consumers unprecedented choice.              │
# │                                                                                                                 │
# │  BYD's commissioning of the world's largest Ro-Ro vessel signifies a commitment to global EV distribution.      │
# │  Looking ahead, expect lower electric car prices, a rapidly expanding charging station network, and improved    │
# │  charging plug compatibility. The future of electric vehicles is bright, accessible, and increasingly           │
# │  convenient.                                                                                                    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭──────────────────────────────────────────────── Task Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: ffb5981d-fc34-4606-900b-e92f41845242                                                                     │
# │  Agent: Creative Writer                                                                                         │
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── Crew Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Completed                                                                                       │
# │  Name: crew                                                                                                     │
# │  ID: 754a1256-c4a3-467b-aafc-60d3b4beda08                                                                       │
# │  Tool Args:                                                                                                     │
# │  Final Output: **The Road Ahead: Electric Vehicle Trends in 2025**                                              │
# │                                                                                                                 │
# │  The electric vehicle revolution is accelerating! Q1 2025 saw a 42% surge in global battery electric vehicle    │
# │  (BEV) sales, contributing to an overall 28% growth in EV sales, with 1.6 million vehicles sold in May alone.   │
# │  The US market boasts nearly 70 EV models from 30 brands, offering consumers unprecedented choice.              │
# │                                                                                                                 │
# │  BYD's commissioning of the world's largest Ro-Ro vessel signifies a commitment to global EV distribution.      │
# │  Looking ahead, expect lower electric car prices, a rapidly expanding charging station network, and improved    │
# │  charging plug compatibility. The future of electric vehicles is bright, accessible, and increasingly           │
# │  convenient.                                                                                                    │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# CrewOutput(raw="**The Road Ahead: Electric Vehicle Trends in 2025**\n\nThe electric vehicle revolution is accelerating! Q1 2025 saw a 42% surge in global battery electric vehicle (BEV) sales, contributing to an overall 28% growth in EV sales, with 1.6 million vehicles sold in May alone. The US market boasts nearly 70 EV models from 30 brands, offering consumers unprecedented choice.\n\nBYD's commissioning of the world's largest Ro-Ro vessel signifies a commitment to global EV distribution. Looking ahead, expect lower electric car prices, a rapidly expanding charging station network, and improved charging plug compatibility. The future of electric vehicles is bright, accessible, and increasingly convenient.", pydantic=None, json_dict=None, tasks_output=[TaskOutput(description='Find 3-5 interesting and recent facts about The future of electrical vehicles as of year 2025.', name=None, expected_output='A bullet list of 3-5 facts', summary='Find 3-5 interesting and recent facts about The future of...', raw="*   In Q1 2025, global battery electric vehicle (BEV) sales witnessed a year-on-year growth of 42%.\n*   Global EV sales grew 28% in 2025, with 1.6 million vehicles sold in May 2025 alone.\n*   There are now almost 70 electric vehicle makes and models available in the US in 2025, from 30 brands - and that number keeps growing.\n*   In 2025, BYD commissioned the world's largest Ro-Ro vessel, bringing its total shipping capacity to more than 30 000 electric cars.\n*   EV trends for 2025 include lower electric car prices, an expansion of charging stations, and greater charging plug compatibility.", pydantic=None, json_dict=None, agent='Research Specialist', output_format=<OutputFormat.RAW: 'raw'>), TaskOutput(description='Write a 100-word blog post summary about The future of electrical vehicles using the facts from the research.', name=None, expected_output='A blog post summary', summary='Write a 100-word blog post summary about The future of...', raw="**The Road Ahead: Electric Vehicle Trends in 2025**\n\nThe electric vehicle revolution is accelerating! Q1 2025 saw a 42% surge in global battery electric vehicle (BEV) sales, contributing to an overall 28% growth in EV sales, with 1.6 million vehicles sold in May alone. The US market boasts nearly 70 EV models from 30 brands, offering consumers unprecedented choice.\n\nBYD's commissioning of the world's largest Ro-Ro vessel signifies a commitment to global EV distribution. Looking ahead, expect lower electric car prices, a rapidly expanding charging station network, and improved charging plug compatibility. The future of electric vehicles is bright, accessible, and increasingly convenient.", pydantic=None, json_dict=None, agent='Creative Writer', output_format=<OutputFormat.RAW: 'raw'>)], token_usage=UsageMetrics(total_tokens=12482, prompt_tokens=11445, cached_prompt_tokens=0, completion_tokens=1037, successful_requests=8))
